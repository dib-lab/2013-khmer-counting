# %% [markdown]
# Other miscellaneous thoughts/questions --
#
#  * do the benchmarks use Eric's bleeding-edge code?
#  * where are the raw data files?
#  * how long does it take to generate the results from scratch?
#
# TODO:
#
# * put together AWS tutorial?

# %% [markdown]
# Figure generation for
# A probabilistic approach to k-mer counting
# =============

# %%
import numpy
datadir = '../data/'

# %%
def get_time_mem(filename):
    "Extract the user time and max memory as generated by 'time' command"
    for line in open(filename):
        line = line.rstrip()
        if 'system' in line:
            fields1 = line.split('user')
            time = fields1[0]
            fields2 = line.split('avgdata ')
            fields3 = fields2[1].split('max')
            mem = fields3[0]
            return float(time), float(mem)

# %%
# read time files

mkindex_time={}
mkindex_mem={}
suffix_time={}
suffix_mem={}

# tallymer runtime info
for i1 in range(1,6):
    for i2 in [1,4]:
        for i3 in [22,31]:
            name = "%d_%d_%d" % (i1, i2, i3)
            filename = 'mkindex_%d_part%d_%d.time' % (i1, i2, i3)
            filename = datadir + filename
            #print filename
            mkindex_time[name],mkindex_mem[name] = get_time_mem(filename)

        name = "%d_%d" % (i1, i2)
        filename = datadir + 'suffix_%d_part%d.time' % (i1, i2)
        #print filename
        suffix_time[name],suffix_mem[name] = get_time_mem(filename)
print "Tallymer suffix"
for key in sort(suffix_time.keys()):
    print key, suffix_time[key],suffix_mem[key]
print "Tallymer mkindex"
for key in sort(mkindex_time.keys()):
    print key, mkindex_time[key],mkindex_mem[key]
    
#print mkindex_time
#print mkindex_mem
#print 'hello'

jelly_count_mem = {}
jelly_count_time = {}
for i1 in range(1,6):
    for i2 in [22,31]:
        name = "%d_%d" % (i1, i2)
        filename = datadir + 'jelly_%d_%d.time1' % (i1, i2)
        jelly_count_time[name],jelly_count_mem[name] = get_time_mem(filename)

#print jelly_count_mem
#print jelly_count_time
print "Jellyfish count"
for key in sort(jelly_count_mem.keys()):
    print key, jelly_count_time[key],jelly_count_mem[key]
    
    
jelly_hist_mem = {}
jelly_hist_time = {}
for i1 in range(1,6):
    for i2 in [22,31]:
        name = "%d_%d" % (i1, i2)
        filename = datadir + 'jelly_%d_%d.time2' % (i1, i2)
        jelly_hist_time[name],jelly_hist_mem[name] = get_time_mem(filename)
#print jelly_hist_mem
#print jelly_hist_time
print "Jellyfish hist"
for key in sort(jelly_hist_mem.keys()):
    print key, jelly_hist_time[key],jelly_hist_mem[key]
    
        
dsk_mem = {}
dsk_time = {}
for i1 in range(1,6):
    for i2 in [22,31]:
        name = "%d_%d" % (i1, i2)
        filename = datadir+'dsk_%d_%d.time' % (i1, i2)
        dsk_time[name], dsk_mem[name] = get_time_mem(filename)
#print dsk_mem
#print dsk_time

print "Dsk"
for key in sort(dsk_mem.keys()):
    print key, dsk_time[key],dsk_mem[key]
    

khmer_mem1 = {}
khmer_time1 = {}

for i1 in range(1,6):
    for i2 in [1,5]:
        for i3 in [22,31]:
            name = "%d_%d_%d" % (i1, i2, i3)
            filename = datadir +'bloom_%d_%d_%d.time1' % (i1, i2, i3)
            khmer_time1[name],khmer_mem1[name] = get_time_mem(filename)
print "khmer_1"
for key in sort(khmer_time1.keys()):
    print key, khmer_time1[key],khmer_mem1[key]
    
    
khmer_mem2 = {}
khmer_time2 = {}

for i1 in range(1,6):
    for i2 in [1,5]:
        for i3 in [22,31]:
            name = "%d_%d_%d" % (i1, i2, i3)
            filename = datadir +'bloom_%d_%d_%d.time2' % (i1, i2, i3)
            khmer_time2[name],khmer_mem2[name] = get_time_mem(filename)
print "khmer_2"
for key in sort(khmer_time2.keys()):
    print key, khmer_time2[key],khmer_mem2[key]
    
    
# other print table, out for other stuffs , draw graphs. 
            
#khmer_mem1, khmer_time1,khmer_mem2, khmer_time2
# Out:
# Tallymer suffix
# 1_1 650.0 6840624.0
# 1_4 632.82 1923272.0
# 2_1 1410.69 13843388.0
# 2_4 1423.54 3875980.0
# 3_1 2133.25 19646612.0
# 3_4 2124.04 5502084.0
# 4_1 2810.56 24995496.0
# 4_4 2810.46 7009516.0
# 5_1 3561.56 30821724.0
# 5_4 3579.41 8633108.0
# Tallymer mkindex
# 1_1_22 198.33 7358536.0
# 1_1_31 204.41 7358524.0
# 1_4_22 197.68 7358532.0
# 1_4_31 203.47 7358516.0
# 2_1_22 453.52 14703436.0
# 2_1_31 475.82 14703408.0
# 2_4_22 453.51 14703436.0
# 2_4_31 474.27 14703408.0
# 3_1_22 680.93 21025704.0
# 3_1_31 719.13 21025796.0
# 3_4_22 683.65 21025680.0
# 3_4_31 718.83 21025792.0
# 4_1_22 891.07 26852456.0
# 4_1_31 942.59 26852456.0
# 4_4_22 892.51 26852460.0
# 4_4_31 949.55 26852452.0
# 5_1_22 1110.66 33199788.0
# 5_1_31 1187.33 33199796.0
# 5_4_22 1110.42 33199804.0
# 5_4_31 1189.04 33199804.0
# Jellyfish count
# 1_22 487.51 4319908.0
# 1_31 509.59 6759480.0
# 2_22 967.78 8199856.0
# 2_31 1005.62 13064064.0
# 3_22 1376.55 9144500.0
# 3_31 1405.24 14008488.0
# ...

# %%
# number of unique 22-mers in different data sets
# 
def get_total_kmers(filename):
    "Extract the user time and max memory as generated by 'time' command"
    total = 0
    for line in open(filename):
        line = line.rstrip()
        fields = line.split()
        total = total + int(fields[1])
    return total
total_list = []
for i in range(1,6):
    filename = datadir+'jelly_%d_22.hist' % (i)
    total = get_total_kmers(filename)
    total_list.append(total)

print total_list
# Out:
# [561179113, 1060376510, 1446022653, 1770849158, 2122080614]

# %% [markdown]
# Figure 1
# =======
# Time usage of different khmer counting tools

# %%
# 1. user time
fig = plt.figure(figsize=(15,6))
ax = fig.add_subplot(111)

L_khmer = [] # 1% error rate , k=22
L_tallymer = [] # k=22, pick biggest memory, suffix 1 part and 4 parts different memory ,but all smaller than mkindex step. 
L_jellyfish_k22 = [] # use k=22, but memory change with different k size. k=31. 
L_dsk = [] # use k=22.

for i in range(1,6):
    L_khmer.append(khmer_time1[str(i)+'_1_22']+khmer_time2[str(i)+'_1_22'])
    L_tallymer.append(suffix_time[str(i)+'_1']+mkindex_time[str(i)+'_1_22'])
    L_jellyfish_k22.append(jelly_count_time[str(i)+'_22'] + jelly_hist_time[str(i)+'_22'])
    L_dsk.append(dsk_time[str(i)+'_22'])



ax.set_xlabel('total number of distinct k-mers')
ax.set_ylabel('Time Usage(s)')


ax.plot(total_list,L_khmer,'bo-', label='khmer')
ax.plot(total_list,L_tallymer,'go-', label='Tallymer')
ax.plot(total_list,L_jellyfish_k22,'ro-', label='Jellyfish')
ax.plot(total_list,L_dsk,'yo-', label='DSK')

ax.set_xlim(0,3e9)
ax.set_ylim(0,6000)
ax.legend(loc='best')
fig_file = '../figure/time_benchmark.pdf'
plt.savefig(fig_file)

# %% [markdown]
# # @CTB Figure 1
#
# The code for generating this figure should be simplified, perhaps at the expense of generality... let's do this together.
#
# Let's make this figure about measuring how long it takes to generate the frequency distribution
# of the k-mers in the data set.  In cases where the program cannot output this directly, just
# make sure that it produces the right output so that we can calculate it from the output.
#
# We should think about how to make Figure 1 clearer.  I have a hard time figuring out how to read it ;).
#
# A few ideas that we could use alone or in combination --
#
# 1. Annotate groups of results on the graph (bracket followed by "khmer", for example)
#
# 2. Multiple panels to emphasize specific points.  Since we will also make the raw data and the notebook available,
#    we can tell people that the entire data set is available if they have questions, although reviewers might hate that...
#
# Anyway, food for thought.

# %% [markdown]
# Figure 2
# =======
# Memory usage of different k-mer counting tools

# %%
# 2. memory usage of different k-mer counting tools

fig = plt.figure(figsize=(15,6))
ax = fig.add_subplot(111)

L_khmer = [] # 1% error rate , k=22
L_tallymer = [] # k=22, pick biggest memory, suffix 1 part and 4 parts different memory ,but all smaller than mkindex step. 
L_jellyfish_k22 = [] # use k=22, but memory change with different k size. k=31. 
L_jellyfish_k31 = []
L_dsk = [] # use k=22.

for i in range(1,6):

    L_khmer.append(khmer_mem2[str(i)+'_1_22']/1000000) # memory usage of step 2 is always bigger than step 1
    
    L_tallymer.append(mkindex_mem[str(i)+'_1_22']/1000000) # memory usage of mkindex is always bigger than suffix(part1/4)
    if jelly_count_mem[str(i)+'_22'] > jelly_hist_mem[str(i)+'_22']:
        L_jellyfish_k22.append(jelly_count_mem[str(i)+'_22']/1000000)
    else:
        L_jellyfish_k22.append(jelly_hist_mem[str(i)+'_22']/1000000)

    if jelly_count_mem[str(i)+'_31'] > jelly_hist_mem[str(i)+'_31']:
        L_jellyfish_k31.append(jelly_count_mem[str(i)+'_31']/1000000)
    else:
        L_jellyfish_k31.append(jelly_hist_mem[str(i)+'_31']/1000000)
        
    L_dsk.append(dsk_mem[str(i)+'_22']/1000000)

#print L_khmer,L_tallymer,L_jellyfish_k22,L_jellyfish_k31,L_dsk

ax.set_xlabel('total number of distinct k-mers')
ax.set_ylabel('Memory Usage(G)')


ax.plot(total_list,L_khmer,'bo-', label='khmer')
ax.plot(total_list,L_tallymer,'go-', label='Tallymer')
ax.plot(total_list,L_jellyfish_k22,'ro-', label='Jellyfish k=22')
ax.plot(total_list,L_jellyfish_k31,'co-', label='Jellyfish k=31')
ax.plot(total_list,L_dsk,'yo-', label='DSK')

ax.set_xlim(0,2.5e9)
ax.set_ylim(0,40)
ax.legend(loc='best')
fig_file = '../figure/memory_benchmark.pdf'
plt.savefig(fig_file)

# %% [markdown]
# # @CTB figure 2
#
# Again, let's work on the code together.
#
# This figure is much easier to read!  More comments/questions:
#
# 1. We should highlight/annotate the "bump" for jellyfish at 2e9 and make sure we explain it in the caption. (I haven't checked to see if you do this already.)
#
# 2. We should also
#
# 3. We could maybe do a second panel or an inset showing the low memory options and how they compare; zooming in on the bottom
#    three lines would presumably be interesting.
#
# Oh, and the xlabel should be changed to "total number of distinct k-mers".
#
# Please simplify the labelling/line color code.

# %% [markdown]
# Figure 3
# =======
# Disk storage usage of different k-mer counting tools

# %%
# 3. disk usage of different k-mer counting tools
fig = plt.figure()
ax = fig.add_subplot(111)

# from size of intermediant files on hard disk, will modify to automatically generate
L_khmer = [5.5,11,15,18,21] # 1% error rate , k=22
L_tallymer = [7.8,17,23,28,36] # k=22, pick biggest memory, suffix 1 part and 4 parts different memory ,but all smaller than mkindex step. 
L_jellyfish_k22 = [5.3,9.9,14,17,20] # use k=22, but memory change with different k size. k=31. 
L_dsk = [1.1,2.1,3.0,3.8,4.7] # use k=22. by default, use the size of reads file as disk usage parameter



ax.set_xlabel('total number of distinct k-mers')
ax.set_ylabel('Disk Usage(G)')

ax.plot(total_list,L_khmer,'bo-', label='khmer')
ax.plot(total_list,L_tallymer,'go-', label='Tallymer')
ax.plot(total_list,L_jellyfish_k22,'ro-', label='Jellyfish')
ax.plot(total_list,L_dsk,'yo-', label='DSK')

 
ax.set_ylim(0,50)
ax.legend(loc='best')
fig_file = '../figure/disk_benchmark.pdf'
plt.savefig(fig_file)

# %% [markdown]
# # @CTB Figure 3
#
# very nice, no comments!
#
# What should we do for DSK disk usage?

# %% [markdown]
# Figure 4
# =======
# relation between average miscount and counting error rate

# %%
ht_size = "100000,200000,400000,600000,800000,1000000,1200000"
HT_SIZE_array = map(int,ht_size.split(','))


file_obj = open(datadir+'fp_assessment.out','r')
lines = file_obj.readlines()
result1 = [map(float,lines[1].split()),map(float,lines[2].split())]
result2 = [map(float,lines[4].split()),map(float,lines[5].split())]
result3 = [map(float,lines[7].split()),map(float,lines[8].split())]
result4 = [map(float,lines[10].split()),map(float,lines[11].split())]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('counting error rate (offset>0)')
ax.set_ylabel('average offset')
ax.plot(result1[1],result1[0],'ro-',result2[1],result2[0],'go-',result3[1],result3[0],'bo-',result4[1],result4[0],'yo-')
#ax.set_xlim(0,1)
#ax.set_ylim(0,20)
ax.legend(('real metagenomics data','simulated k-mers','simulated reads with error','simulated reads without error'),loc='best')
fig_file = '../figure/average_offset_vs_fpr.pdf'
plt.savefig(fig_file)
ax.axis(ymax=5)
# Out:
# (0.30000000000000004, 1.0, 0.0, 5)

# %% [markdown]
# # @CTB Figure 4
#
# Again, very nice
#
# Let's set the ymax to be five here.
#
# Can we generate stddev bars? Are they interesting?

# %% [markdown]
# Figure 5
# =======
# Percentage of the unique k-mers starting in different position in reads

# %%
file17 = open(datadir+"ecoli_ref.fastq.fasta.pos.abund=1",'r')
file32 = open(datadir+"ecoli_ref.fastq.fasta.pos32.abund=1",'r')

list1 = []
list2 = []
x1 = []
x2 = []

for line in file17:
    line = line.rstrip()
    fields = line.split()
    if fields[1] != '0':
        x1.append(float(fields[0]))
        list1.append(float(fields[1]))

for line in file32:
    line = line.rstrip()
    fields = line.split()
    if fields[1] != '0':
        x2.append(float(fields[0]))
        list2.append(float(fields[1]))

plt.xlabel("starting position of k-mer")
plt.ylabel("number of abund=1 k-mers at that position")
plt.title("low-abundance k-mer distribution within reads")


plt.plot(x1,list1,'r-')
plt.plot(x2,list2,'b-')
plt.legend(('k=17','k=32'),)
plt.ylim(0,10000000)
plt.xlim(0,100)

plt.savefig("../figure/perc_unique_pos.pdf")

# %% [markdown]
# # @CTB figure 5
#
# Very nice, no comments.  Well, maybe we should just use these as lines instead of data points?

# %% [markdown]
# Figure 6
# =======
# Number of remaining reads after iterating filtering out low-abundance reads

# %%
# 6. abundance filtering 1 . number of remaining reads
fig = plt.figure()
ax = fig.add_subplot(111)

list2_x = np.arange(4)*4

list2_y1 = [42458402,42458402,42458402,42458402] # # of original reads
list2_y2 = [29766743,28143413,27554119,27255073] # hashtable size: 1e8
list2_y3 = [29262271,27990879,27481113,27212873] # hashtable size: 1e9

ax.set_ylabel('number of remaining reads')

width = 1
rects1 = ax.bar(list2_x+1,list2_y1,width,color='g')
rects2 = ax.bar(list2_x+1+width*1,list2_y2,width,color='r')
rects3 = ax.bar(list2_x+1+width*2,list2_y3,width,color='c')


ax.set_xticks(list2_x+2.5)
ax.set_xticklabels(('1st run','2nd run','3rd run','4th run'))

ax.set_ylim((1,6e7))
ax.set_xlim(0,17)

plt.legend((rects1[0],rects2[0],rects3[0]),('# of original reads','hashtable size: 1e8','hashtable size: 1e9'),loc='best')
fig_file = '../figure/num_remaining_reads.pdf'
plt.savefig(fig_file)

# %% [markdown]
# # @CTB Figure 6
#
# Vaguely unhappy with these figures.  It may just be the colors... ;)
#
# My main two comments:
#
#  * I worry that the hashtable sizes are arbitrary.  What are the FP rates for these two sizes?
#  * Sort of connected: can you think of a way to highlight the difference bteween red and blue for each run?  doesn't seem like much diff.

# %% [markdown]
# Figure 7
# =======
# number of reads with low-abundance k-mers after iterating filtering out low-abundance reads

# %%
# 7. abundance filtering 2 . percentage of remaining reads
fig = plt.figure()
ax = fig.add_subplot(111)

list2_x = np.arange(4)*3


list2_y1 = [29766743*0.01*8.26,28143413*0.01*4.62,27554119*0.01*3.69,27255073*0.01*3.30] # hashtable size: 1e8
list2_y2 = [29262271*0.01*6.68,27990879*0.01*4.34,27481113*0.01*3.59,27212873*0.01*3.24] # hashtable size: 1e9

ax.set_ylabel('number of reads with low-abundance k-mers')

width = 1
rects1 = ax.bar(list2_x+1,list2_y1,width,color='r')
rects2 = ax.bar(list2_x+1+width*1,list2_y2,width,color='c')



ax.set_xticks(list2_x+2)
ax.set_xticklabels(('1st run','2nd run','3rd run','4th run'))

ax.set_ylim((0,3e6))
ax.set_xlim(0,13)

plt.legend((rects1[0],rects2[0]),('hashtable size: 1e8','hashtable size: 1e9'),loc='best')
fig_file = '../figure/num_bad_reads.pdf'
plt.savefig(fig_file)

# %% [markdown]
# # @CTB Figure 7
#
# Similar comments as for figure 6, but the differences are magnified here.  Nice.

# %% [markdown]
# Figure 8
# =======
# percentage of incorrect reads in the remaining reads after iterating filtering

# %%
# 7. abundance filtering 2 . percentage of remaining reads
fig = plt.figure()
ax = fig.add_subplot(111)

list2_x = np.arange(4)*3


list2_y1 = [8.26,4.62,3.69,3.30] # hashtable size: 1e8
list2_y2 = [6.68,4.34,3.59,3.24] # hashtable size: 1e9

ax.set_ylabel('% of incorrect reads remaining')

width = 1
rects1 = ax.bar(list2_x+1,list2_y1,width,color='r')
rects2 = ax.bar(list2_x+1+width*1,list2_y2,width,color='c')



ax.set_xticks(list2_x+2)
ax.set_xticklabels(('1st run','2nd run','3rd run','4th run'))

ax.set_ylim((1,10))
ax.set_xlim(0,13)

plt.legend((rects1[0],rects2[0]),('hashtable size: 1e8','hashtable size: 1e9'),loc='best')
fig_file = '../figure/perc_remaining_reads.pdf'
plt.savefig(fig_file)

# %% [markdown]
# # @CTB Figure 8
#
# This looks pretty redundant with Figure 7, honestly ;).
